# %%
import pandas as pd

# %%
#read the file from the local computer
df = pd.read_csv('/Users/angelis/Downloads/sales_data.csv')

# %%
# check the data frame 
df
# Out:
#          Product    Region   Price  Units Sold   Sale Date
# 0            NaN  Region_6   75.96        10.0  2022-01-01
# 1            NaN  Region_1  175.78         8.0  2022-01-02
# 2     Product_46  Region_3   20.43        12.0  2022-01-03
# 3     Product_36  Region_1   12.77        10.0  2022-01-04
# 4     Product_17  Region_6  125.69         6.0  2022-01-05
# ...          ...       ...     ...         ...         ...
# 1045  Product_45  Region_7   78.69         8.0  2022-07-28
# 1046   Product_1  Region_6     NaN         8.0  2022-08-02
# 1047  Product_17  Region_2  114.37        11.0  2023-12-18
# 1048         NaN  Region_8     NaN         5.0  2023-12-27
# 1049  Product_16  Region_2   69.30         8.0  2024-02-23
#
# [1050 rows x 5 columns]

# %%
#check the information of the dataframe 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1050 entries, 0 to 1049
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Product     947 non-null    object
#  1   Region      946 non-null    object
#  2   Price       945 non-null    float64
#  3   Units Sold  946 non-null    float64
#  4   Sale Date   1050 non-null   object
# dtypes: float64(2), object(3)
# memory usage: 41.1+ KB

# %%
#check the number and number of null value of data for each column.
df.describe(include='all')
# Out:
#            Product    Region        Price  Units Sold   Sale Date
# count          947       946   945.000000  946.000000        1050
# unique          50        10          NaN         NaN        1000
# top     Product_45  Region_9          NaN         NaN  2022-07-28
# freq            28       109          NaN         NaN           2
# mean           NaN       NaN   107.598688   10.048626         NaN
# std            NaN       NaN   124.020322    3.172261         NaN
# min            NaN       NaN     0.200000    2.000000         NaN
# 25%            NaN       NaN    29.430000    8.000000         NaN
# 50%            NaN       NaN    78.130000   10.000000         NaN
# 75%            NaN       NaN   142.570000   12.000000         NaN
# max            NaN       NaN  2143.300000   22.000000         NaN

# %%
#data cleaning started
#find the null value in Price and Units Sold column and fill them in with the average value of these two column. Because the Sale Date column has no null value, so there is no need to fill.
df['Price']=df['Price'].fillna(df['Price'].mean())
df['Units Sold']=df['Units Sold'].fillna(df['Units Sold'].mean())

# %%
# after filling the null value in these two column, check the number of data in Price and Units Sold column is 1050 or not.
df.describe(include='all')
# Out:
#            Product    Region        Price   Units Sold   Sale Date
# count          947       946  1050.000000  1050.000000        1050
# unique          50        10          NaN          NaN        1000
# top     Product_45  Region_9          NaN          NaN  2022-07-28
# freq            28       109          NaN          NaN           2
# mean           NaN       NaN   107.598688    10.048626         NaN
# std            NaN       NaN   117.649777     3.010905         NaN
# min            NaN       NaN     0.200000     2.000000         NaN
# 25%            NaN       NaN    33.855000     8.000000         NaN
# 50%            NaN       NaN    88.445000    10.000000         NaN
# 75%            NaN       NaN   133.300000    12.000000         NaN
# max            NaN       NaN  2143.300000    22.000000         NaN

# %%
# drop the row with the null value in Product and Region column, and describe the dataframe after that.
df = df.dropna()
df.describe(include = 'all')
# Out:
#           Product    Region        Price  Units Sold   Sale Date
# count         853       853   853.000000  853.000000         853
# unique         50        10          NaN         NaN         810
# top     Product_5  Region_9          NaN         NaN  2022-07-28
# freq           28       101          NaN         NaN           2
# mean          NaN       NaN   108.517905   10.086738         NaN
# std           NaN       NaN   122.624190    3.076829         NaN
# min           NaN       NaN     0.200000    2.000000         NaN
# 25%           NaN       NaN    34.160000    8.000000         NaN
# 50%           NaN       NaN    88.450000   10.000000         NaN
# 75%           NaN       NaN   131.410000   12.000000         NaN
# max           NaN       NaN  2143.300000   22.000000         NaN

# %%
#check if there is no null remain in the dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 853 entries, 2 to 1049
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Product     853 non-null    object
#  1   Region      853 non-null    object
#  2   Price       853 non-null    float64
#  3   Units Sold  853 non-null    float64
#  4   Sale Date   853 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 40.0+ KB

# %%
# cleaning the dataframe by dropping the duplications 
df = df.drop_duplicates()
df
# Out:
#         Product     Region   Price  Units Sold   Sale Date
# 2    Product_46   Region_3   20.43   12.000000  2022-01-03
# 3    Product_36   Region_1   12.77   10.000000  2022-01-04
# 4    Product_17   Region_6  125.69    6.000000  2022-01-05
# 5    Product_45   Region_1    8.63   11.000000  2022-01-06
# 6    Product_31   Region_3   23.73    6.000000  2022-01-07
# ..          ...        ...     ...         ...         ...
# 988  Product_42   Region_9  240.97   10.048626  2024-09-15
# 993   Product_7   Region_9  128.51   17.000000  2024-09-20
# 994   Product_1   Region_4   95.24    7.000000  2024-09-21
# 998   Product_2  Region_10   43.44   15.000000  2024-09-25
# 999  Product_35   Region_8   56.95    6.000000  2024-09-26
#
# [810 rows x 5 columns]

# %%
# Adding a new column Revenue which is the product of Price and Units sold 
df['Revenue']= df['Price'] * df['Units Sold']

df
#finished Data cleaning
# Out:
#                Region   Price  Units Sold   Sale Date      Revenue
# Product
# Product_46   Region_3   20.43   12.000000  2022-01-03   245.160000
# Product_36   Region_1   12.77   10.000000  2022-01-04   127.700000
# Product_17   Region_6  125.69    6.000000  2022-01-05   754.140000
# Product_45   Region_1    8.63   11.000000  2022-01-06    94.930000
# Product_31   Region_3   23.73    6.000000  2022-01-07   142.380000
# ...               ...     ...         ...         ...          ...
# Product_42   Region_9  240.97   10.048626  2024-09-15  2421.417357
# Product_7    Region_9  128.51   17.000000  2024-09-20  2184.670000
# Product_1    Region_4   95.24    7.000000  2024-09-21   666.680000
# Product_2   Region_10   43.44   15.000000  2024-09-25   651.600000
# Product_35   Region_8   56.95    6.000000  2024-09-26   341.700000
#
# [810 rows x 5 columns]

# %%
#Check the dataframe after remove the duplication and adding the new column
df.describe()
# Out:
#              Price  Units Sold       Revenue
# count   810.000000  810.000000    810.000000
# mean    107.011208   10.098570   1054.924810
# std     122.268623    3.067497   1106.985403
# min       0.200000    2.000000      0.990000
# 25%      33.805000    8.000000    297.525000
# 50%      87.775000   10.000000    798.865000
# 75%     129.317500   12.000000   1398.782942
# max    2143.300000   22.000000  10716.500000

# %%
# Finding the maximum value of Revenue in the dataframe 
df.loc[df['Revenue']==df['Revenue'].max()]
# Out:
#               Region   Price  Units Sold   Sale Date  Revenue
# Product
# Product_15  Region_8  2143.3         5.0  2024-08-27  10716.5

# %%
#Group the dataframe by Region 
df_grouped = df.groupby('Region')

# %%
#Check the Maximum and Minimum value of Price, Units Sold and Revenue for each region 
df_grouped.describe()
# Out:
#           Price
#           count        mean         std   min      25%      50%         75%
# Region
# Region_1   73.0  100.894359  114.263187  0.96  29.3900   90.000  110.370000  \
# Region_10  90.0   97.019342   89.327082  5.48  33.8825   78.645  107.598688
# Region_2   71.0  128.478903  123.662082  2.14  29.1350   99.320  202.290000
# Region_3   79.0   97.737142   92.976562  1.29  28.7400   94.920  116.320000
# Region_4   92.0  106.449597   96.109663  0.20  40.8075   95.510  126.040000
# Region_5   84.0   99.333907   82.571703  0.31  39.4225   84.005  131.942500
# Region_6   76.0   90.917064   91.322040  0.54  31.3175   64.385  107.598688
# Region_7   64.0   92.494992   86.117632  0.61  26.9050   85.435  107.598688
# Region_8   85.0  145.367641  249.479210  0.61  38.1500  101.120  166.320000
# Region_9   96.0  108.497667   89.285009  0.33  41.0450   95.565  140.555000
#
#                    Units Sold             ...              Revenue
# ...

# %%
#import the matplotlib and seaborn 
# Visulize the total Revenue for each region by using plt function


# Plot a histogram of revenue by region
plt.figure(figsize=(10, 6))
df.groupby('Region')['Revenue'].sum().plot(kind='bar')
plt.xlabel('Region')
plt.ylabel('Total Revenue Sold')
plt.title('Total Revenue by Region')
plt.show()

# %%
# By analyze the histogram above, we can tell the revenue of Region 8 is the highest and the revenue of region 7 is lowest
# Here we trying to understand what is the max and min revenue for region 7 
df_Region_7=df[df['Region']=='Region_7']
df_Region_7.loc[df_Region_7['Revenue']==df_Region_7['Revenue'].max()]
# Out:
#               Region   Price  Units Sold   Sale Date  Revenue
# Product
# Product_14  Region_7  517.29        10.0  2022-09-22   5172.9

# %%
df_Region_7.loc[df_Region_7['Revenue']==df_Region_7['Revenue'].min()]
# Out:
#               Region  Price  Units Sold   Sale Date  Revenue
# Product
# Product_13  Region_7   0.61        19.0  2024-08-20    11.59

# %%
# Here we trying to understand what is the max and min revenue for region 8 

df_Region_8=df[df['Region']=='Region_8']
df_Region_8.loc[df_Region_8['Revenue']==df_Region_8['Revenue'].max()]
# Out:
#               Region   Price  Units Sold   Sale Date  Revenue
# Product
# Product_15  Region_8  2143.3         5.0  2024-08-27  10716.5

# %%
df_Region_8.loc[df_Region_8['Revenue']==df_Region_8['Revenue'].min()]
# Out:
#               Region  Price  Units Sold   Sale Date  Revenue
# Product
# Product_27  Region_8   0.61        10.0  2023-12-05      6.1

# %%
#1) What conclusions can you draw about the sales performance of various products and regions?
# - For this business, the revenue in Region 8 has the best performance compared to other regions.
# - For this business, the revenue in Region 7 is the lowest compared to other regions.
# - Product 15 has the highest revenue in Region 8, and Product 27 has the poorest revenue. 
# - Product 14 has the highest revenue in Region 7, and Product 13 has the poorest revenue.

 
#2) What recommendations do you have for the business?
# - I recommend this business invest more in product15 and reduce the cost input for product 27 in this region
# - I recommend this business investigate Region 7 and see why product 13 has a very bad performance in this region. Given the information, there is no conclusion drawn

#3) Describe your data-cleaning approach. How and why did you decide on which cleaning techniques to use?
# - In the first step, find the null value in the Price and Units Sold column and fill them in with the average value of these two columns. Because of fill in the mean value of these two columns would not change the total mean after the filling, that will not change the descriptive statistics of this data frame. Because the Sale Date column has no null value, so there is no need to fill it. The technique I used is fillna(df['The column'].mean())
# - After filling in the null value in these two columns, check the number of data in the Price and Units Sold column is 1050 or not. 
# - In the second step, drop the row with the null value in the Product and Region column, and describe the data frame after that. NULL is not a value and therefore has no intrinsic data type, there is no way you can analyze data with no value which is why we need to remove them. The technique is df. drop()
# - On the third step, cleaning the data frame by dropping the duplications may be caused by input error. Because of the existence of duplications, the data frame will be inaccurate to analyze. The technique is df.drop_duplicates()
# - In the fouth step, I added a new column Revenue which is the product of Price and Units sold. THe techenique is df['Revenue']= df['Price'] * df['Units Sold']
